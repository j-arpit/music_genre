# %%
# %config Completer.use_jedi = False
import pandas as pd

# %%
df = pd.read_csv("wine_train.csv")

# %%
df
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               9.0             0.245         0.38             5.9      0.045
# 1               8.2             0.420         0.29             4.1      0.030
# 2               6.4             0.220         0.32             7.2      0.028
# 3               5.0             0.350         0.25             7.8      0.031
# 4               7.4             0.300         0.30             5.2      0.053
# ...             ...               ...          ...             ...        ...
# 3668            7.1             0.340         0.32             2.0      0.051
# 3669            6.4             0.290         0.57             1.0      0.060
# 3670            8.0             0.260         0.28             8.2      0.038
# 3671            6.7             0.150         0.29             5.0      0.058
# 3672            6.4             0.230         0.26             8.1      0.054
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3673 entries, 0 to 3672
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         3673 non-null   float64
#  1   volatile.acidity      3673 non-null   float64
#  2   citric.acid           3673 non-null   float64
#  3   residual.sugar        3673 non-null   float64
#  4   chlorides             3673 non-null   float64
#  5   free.sulfur.dioxide   3673 non-null   float64
#  6   total.sulfur.dioxide  3673 non-null   float64
#  7   density               3673 non-null   float64
#  8   pH                    3673 non-null   float64
#  9   sulphates             3673 non-null   float64
#  10  alcohol               3673 non-null   float64
#  11  quality               3673 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 344.5 KB

# %%
df.quality.unique()
# Out:
# array([6, 7, 8, 5, 3, 4, 9], dtype=int64)

# %%
df.mean()
# Out:
# fixed.acidity             6.854724
# volatile.acidity          0.277953
# citric.acid               0.335108
# residual.sugar            6.413613
# chlorides                 0.045710
# free.sulfur.dioxide      35.368500
# total.sulfur.dioxide    138.626736
# density                   0.994026
# pH                        3.189834
# sulphates                 0.489115
# alcohol                  10.525709
# quality                   5.893820
# dtype: float64

# %%
df.quality.value_counts()
# Out:
# 6    1647
# 5    1071
# 7     671
# 8     143
# 4     123
# 3      14
# 9       4
# Name: quality, dtype: int64

# %%
df.describe()
# Out:
#        fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# count    3673.000000       3673.000000  3673.000000     3673.000000
# mean        6.854724          0.277953     0.335108        6.413613
# std         0.848973          0.099913     0.123156        5.054275
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.310000        5.250000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free.sulfur.dioxide  total.sulfur.dioxide      density  \
# count  3673.000000          3673.000000           3673.000000  3673.000000
# mean      0.045710            35.368500            138.626736     0.994026
# std       0.021747            16.974746             42.641142     0.003016
# ...

# %%
new = df["quality"].isin([6])
df[new]
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               9.0             0.245         0.38             5.9      0.045
# 3               5.0             0.350         0.25             7.8      0.031
# 4               7.4             0.300         0.30             5.2      0.053
# 7               6.8             0.210         0.37             7.0      0.038
# 9               6.1             0.410         0.00             1.6      0.063
# ...             ...               ...          ...             ...        ...
# 3664            5.7             0.250         0.27            10.8      0.050
# 3665            6.8             0.270         0.37             8.2      0.055
# 3666            6.0             0.170         0.36             1.7      0.042
# 3668            7.1             0.340         0.32             2.0      0.051
# 3670            8.0             0.260         0.28             8.2      0.038
#
# ...

# %%
gk = df.groupby('quality')

# %%
gk.first()
# Out:
#          fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# quality
# 3                  7.9             0.640         0.46            10.6
# 4                  7.7             0.280         0.63            11.1
# 5                  6.6             0.240         0.22            12.3
# 6                  9.0             0.245         0.38             5.9
# 7                  8.2             0.420         0.29             4.1
# 8                  6.4             0.220         0.32             7.2
# 9                  7.4             0.240         0.36             2.0
#
#          chlorides  free.sulfur.dioxide  total.sulfur.dioxide  density    pH  \
# quality
# 3            0.244                 33.0                 227.0  0.99830  2.87
# 4            0.039                 58.0                 179.0  0.99790  3.08
# 5            0.051                 35.0                 146.0  0.99676  3.10
# 6            0.045                 52.0                 159.0  0.99500  2.93
# ...

# %%
gk.get_group(6)
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               9.0             0.245         0.38             5.9      0.045
# 3               5.0             0.350         0.25             7.8      0.031
# 4               7.4             0.300         0.30             5.2      0.053
# 7               6.8             0.210         0.37             7.0      0.038
# 9               6.1             0.410         0.00             1.6      0.063
# ...             ...               ...          ...             ...        ...
# 3664            5.7             0.250         0.27            10.8      0.050
# 3665            6.8             0.270         0.37             8.2      0.055
# 3666            6.0             0.170         0.36             1.7      0.042
# 3668            7.1             0.340         0.32             2.0      0.051
# 3670            8.0             0.260         0.28             8.2      0.038
#
# ...

# %%
df = pd.read_csv("sales_data_types.csv")

# %%
df
# Out:
#    Customer Number     Customer Name         2016          2017  \
# 0          10002.0  Quest Industries  $125,000.00    $162500.00
# 1         552278.0    Smith Plumbing  $920,000.00  $101,2000.00
# 2          23477.0   ACME Industrial   $50,000.00     $62500.00
# 3          24900.0        Brekke LTD  $350,000.00    $490000.00
# 4         651029.0         Harbor Co   $15,000.00     $12750.00
#
#   Percent Growth Jan Units  Month  Day  Year Active
# 0         30.00%       500      1   10  2015      Y
# 1         10.00%       700      6   15  2014      Y
# 2         25.00%       125      3   29  2016      Y
# 3          4.00%        75     10   27  2015      Y
# 4        -15.00%    Closed      2    2  2014      N

# %%
df["2016"] + df["2017"]
# Out:
# 0      $125,000.00$162500.00
# 1    $920,000.00$101,2000.00
# 2        $50,000.00$62500.00
# 3      $350,000.00$490000.00
# 4        $15,000.00$12750.00
# dtype: object

# %%
def convert_currency(val):
    newval = val.replace(",", "").replace("$", "")
    return float(newval)

# %%
df['2016'] = df['2016'].apply(convert_currency)

# %%
df
# Out:
#    Customer Number     Customer Name      2016          2017 Percent Growth  \
# 0          10002.0  Quest Industries  125000.0    $162500.00         30.00%
# 1         552278.0    Smith Plumbing  920000.0  $101,2000.00         10.00%
# 2          23477.0   ACME Industrial   50000.0     $62500.00         25.00%
# 3          24900.0        Brekke LTD  350000.0    $490000.00          4.00%
# 4         651029.0         Harbor Co   15000.0     $12750.00        -15.00%
#
#   Jan Units  Month  Day  Year Active
# 0       500      1   10  2015      Y
# 1       700      6   15  2014      Y
# 2       125      3   29  2016      Y
# 3        75     10   27  2015      Y
# 4    Closed      2    2  2014      N

# %%
df['2017'] = df['2017'].apply(lambda x: x.replace(",", "").replace("$", "")).astype(float)

# %%
df.dtypes
# Out:
# Customer Number    float64
# Customer Name       object
# 2016               float64
# 2017               float64
# Percent Growth      object
# Jan Units           object
# Month                int64
# Day                  int64
# Year                 int64
# Active              object
# dtype: object

# %%
df['Percent Growth'] = df['Percent Growth'].apply(lambda x: x.replace("%", "")).astype(float)/100

# %%
df['Active'].astype(bool)  ## this is not working
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Active, dtype: bool

# %%
import numpy as np

# %%
df['Active'] = np.where(df['Active'] == 'Y', True, False )

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0          10002.0  Quest Industries  125000.0   162500.0            0.30
# 1         552278.0    Smith Plumbing  920000.0  1012000.0            0.10
# 2          23477.0   ACME Industrial   50000.0    62500.0            0.25
# 3          24900.0        Brekke LTD  350000.0   490000.0            0.04
# 4         651029.0         Harbor Co   15000.0    12750.0           -0.15
#
#   Jan Units  Month  Day  Year  Active
# 0       500      1   10  2015    True
# 1       700      6   15  2014    True
# 2       125      3   29  2016    True
# 3        75     10   27  2015    True
# 4    Closed      2    2  2014   False

# %%
# df['Jan Units'].astype('int') # this will give error becuase it contains closed as a value
pd.to_numeric(df['Jan Units'], errors = 'coerce').fillna(0)
# Out:
# 0    500.0
# 1    700.0
# 2    125.0
# 3     75.0
# 4      0.0
# Name: Jan Units, dtype: float64

# %%
pd.to_datetime(df[['Month', 'Day', 'Year']])
# Out:
# 0   2015-01-10
# 1   2014-06-15
# 2   2016-03-29
# 3   2015-10-27
# 4   2014-02-02
# dtype: datetime64[ns]

# %%
df["Start_Date"] = pd.to_datetime(df[['Month', 'Day', 'Year']])
df["Jan Units"] = pd.to_numeric(df['Jan Units'], errors='coerce').fillna(0)

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0          10002.0  Quest Industries  125000.0   162500.0            0.30
# 1         552278.0    Smith Plumbing  920000.0  1012000.0            0.10
# 2          23477.0   ACME Industrial   50000.0    62500.0            0.25
# 3          24900.0        Brekke LTD  350000.0   490000.0            0.04
# 4         651029.0         Harbor Co   15000.0    12750.0           -0.15
#
#    Jan Units  Month  Day  Year  Active Start_Date
# 0      500.0      1   10  2015    True 2015-01-10
# 1      700.0      6   15  2014    True 2014-06-15
# 2      125.0      3   29  2016    True 2016-03-29
# 3       75.0     10   27  2015    True 2015-10-27
# 4        0.0      2    2  2014   False 2014-02-02

# %%
df_2 = pd.read_csv("sales_data_types.csv",
                   dtype={'Customer Number': 'int'},
                   converters={'2016': convert_currency,
                               '2017': convert_currency,
                               'Percent Growth': lambda x: float(x.replace("%", ""))/100,
                               'Jan Units': lambda x: pd.to_numeric(x, errors='coerce'),
                               'Active': lambda x: np.where(x == "Y", True, False)
                              })

# %%
df_2
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0            10002  Quest Industries  125000.0   162500.0            0.30
# 1           552278    Smith Plumbing  920000.0  1012000.0            0.10
# 2            23477   ACME Industrial   50000.0    62500.0            0.25
# 3            24900        Brekke LTD  350000.0   490000.0            0.04
# 4           651029         Harbor Co   15000.0    12750.0           -0.15
#
#    Jan Units  Month  Day  Year Active
# 0      500.0      1   10  2015   True
# 1      700.0      6   15  2014   True
# 2      125.0      3   29  2016   True
# 3       75.0     10   27  2015   True
# 4        NaN      2    2  2014  False

# %%
df_2['total'] = df_2['2016']+df_2['2017']

# %%
df_2
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0            10002  Quest Industries  125000.0   162500.0            0.30
# 1           552278    Smith Plumbing  920000.0  1012000.0            0.10
# 2            23477   ACME Industrial   50000.0    62500.0            0.25
# 3            24900        Brekke LTD  350000.0   490000.0            0.04
# 4           651029         Harbor Co   15000.0    12750.0           -0.15
#
#    Jan Units  Month  Day  Year Active      total
# 0      500.0      1   10  2015   True   287500.0
# 1      700.0      6   15  2014   True  1932000.0
# 2      125.0      3   29  2016   True   112500.0
# 3       75.0     10   27  2015   True   840000.0
# 4        NaN      2    2  2014  False    27750.0

# %%
df['total'] = df['2016']+df['2017']
df.rename(columns={'total': 'total_sum'}, inplace = True)

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0          10002.0  Quest Industries  125000.0   162500.0            0.30
# 1         552278.0    Smith Plumbing  920000.0  1012000.0            0.10
# 2          23477.0   ACME Industrial   50000.0    62500.0            0.25
# 3          24900.0        Brekke LTD  350000.0   490000.0            0.04
# 4         651029.0         Harbor Co   15000.0    12750.0           -0.15
#
#    Jan Units  Month  Day  Year  Active Start_Date  total_sum
# 0      500.0      1   10  2015    True 2015-01-10   287500.0
# 1      700.0      6   15  2014    True 2014-06-15  1932000.0
# 2      125.0      3   29  2016    True 2016-03-29   112500.0
# 3       75.0     10   27  2015    True 2015-10-27   840000.0
# 4        0.0      2    2  2014   False 2014-02-02    27750.0

# %%
total_sum = df.pop('total_sum')

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0          10002.0  Quest Industries  125000.0   162500.0            0.30
# 1         552278.0    Smith Plumbing  920000.0  1012000.0            0.10
# 2          23477.0   ACME Industrial   50000.0    62500.0            0.25
# 3          24900.0        Brekke LTD  350000.0   490000.0            0.04
# 4         651029.0         Harbor Co   15000.0    12750.0           -0.15
#
#    Jan Units  Month  Day  Year  Active Start_Date
# 0      500.0      1   10  2015    True 2015-01-10
# 1      700.0      6   15  2014    True 2014-06-15
# 2      125.0      3   29  2016    True 2016-03-29
# 3       75.0     10   27  2015    True 2015-10-27
# 4        0.0      2    2  2014   False 2014-02-02

# %%
total_sum
# Out:
# 0     287500.0
# 1    1932000.0
# 2     112500.0
# 3     840000.0
# 4      27750.0
# Name: total_sum, dtype: float64

# %%
df.insert(0, 'total', total_sum)

# %%
df
# Out:
#        total  Customer Number     Customer Name      2016       2017  \
# 0   287500.0          10002.0  Quest Industries  125000.0   162500.0
# 1  1932000.0         552278.0    Smith Plumbing  920000.0  1012000.0
# 2   112500.0          23477.0   ACME Industrial   50000.0    62500.0
# 3   840000.0          24900.0        Brekke LTD  350000.0   490000.0
# 4    27750.0         651029.0         Harbor Co   15000.0    12750.0
#
#    Percent Growth  Jan Units  Month  Day  Year  Active Start_Date
# 0            0.30      500.0      1   10  2015    True 2015-01-10
# 1            0.10      700.0      6   15  2014    True 2014-06-15
# 2            0.25      125.0      3   29  2016    True 2016-03-29
# 3            0.04       75.0     10   27  2015    True 2015-10-27
# 4           -0.15        0.0      2    2  2014   False 2014-02-02

# %%
df.count()
# Out:
# total              5
# Customer Number    5
# Customer Name      5
# 2016               5
# 2017               5
# Percent Growth     5
# Jan Units          5
# Month              5
# Day                5
# Year               5
# Active             5
# Start_Date         5
# dtype: int64

# %%
df.median()
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   """Entry point for launching an IPython kernel.
# total              287500.0
# Customer Number     24900.0
# 2016               125000.0
# 2017               162500.0
# Percent Growth          0.1
# Jan Units             125.0
# Month                   3.0
# Day                    15.0
# Year                 2015.0
# Active                  1.0
# dtype: float64

# %%
df.max()
# Out:
# total                        1932000.0
# Customer Number               651029.0
# Customer Name           Smith Plumbing
# 2016                          920000.0
# 2017                         1012000.0
# Percent Growth                     0.3
# Jan Units                        700.0
# Month                               10
# Day                                 29
# Year                              2016
# Active                            True
# Start_Date         2016-03-29 00:00:00
# dtype: object

# %%
df.pivot_table(index='total',values=['2016','2017'],aggfunc=np.mean)
# Out:
#                2016       2017
# total
# 27750.0     15000.0    12750.0
# 112500.0    50000.0    62500.0
# 287500.0   125000.0   162500.0
# 840000.0   350000.0   490000.0
# 1932000.0  920000.0  1012000.0
